# %%
import numpy as np

# %%
import pandas as pd

# %%
example_data= np.random.randn(5,3)
example_data
# Out:
# array([[ 0.63498476,  0.99088119, -1.82320192],
#        [ 0.28272441, -1.77539133, -2.17636095],
#        [ 0.38436306,  0.29406158, -0.30549343],
#        [-0.88324898,  0.55314412,  0.86802951],
#        [-0.11937549,  0.53817934,  0.51112201]])

# %%
example_dataframe=pd.DataFrame(example_data)

# %%
print(example_dataframe)
# Out:
#           0         1         2
# 0  0.634985  0.990881 -1.823202
# 1  0.282724 -1.775391 -2.176361
# 2  0.384363  0.294062 -0.305493
# 3 -0.883249  0.553144  0.868030
# 4 -0.119375  0.538179  0.511122

# %%
type(example_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
print(example_dataframe[0])
# Out:
# 0    0.634985
# 1    0.282724
# 2    0.384363
# 3   -0.883249
# 4   -0.119375
# Name: 0, dtype: float64

# %%
type(example_dataframe[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(example_data, index= ["Ali","Ömer","Yusuf","Cennet","Furkan"], columns= ["Price","Age","Seniorty"])
new_df
# Out:
#            Price       Age  Seniorty
# Ali     0.634985  0.990881 -1.823202
# Ömer    0.282724 -1.775391 -2.176361
# Yusuf   0.384363  0.294062 -0.305493
# Cennet -0.883249  0.553144  0.868030
# Furkan -0.119375  0.538179  0.511122

# %%
print(new_df["Age"])
# Out:
# Ali       0.990881
# Ömer     -1.775391
# Yusuf     0.294062
# Cennet    0.553144
# Furkan    0.538179
# Name: Age, dtype: float64

# %%
print(new_df["Seniorty"])
# Out:
# Ali      -1.823202
# Ömer     -2.176361
# Yusuf    -0.305493
# Cennet    0.868030
# Furkan    0.511122
# Name: Seniorty, dtype: float64

# %%
print(new_df[["Age","Price"]])
# Out:
#              Age     Price
# Ali     0.990881  0.634985
# Ömer   -1.775391  0.282724
# Yusuf   0.294062  0.384363
# Cennet  0.553144 -0.883249
# Furkan  0.538179 -0.119375

# %%
print(new_df.loc["Ömer"])
# Out:
# Price       0.282724
# Age        -1.775391
# Seniorty   -2.176361
# Name: Ömer, dtype: float64

# %%
print(new_df.loc["Cennet"])
# Out:
# Price      -0.883249
# Age         0.553144
# Seniorty    0.868030
# Name: Cennet, dtype: float64

# %%
print(new_df.iloc[4])
# Out:
# Price      -0.119375
# Age         0.538179
# Seniorty    0.511122
# Name: Furkan, dtype: float64

# %%
print(new_df.iloc[2])
# Out:
# Price       0.384363
# Age         0.294062
# Seniorty   -0.305493
# Name: Yusuf, dtype: float64

# %%
#: tüm satırları seçer sonraki sayı ise istenilen indexteki kolonu getirir.
print(new_df.iloc[:,2])
# Out:
# Ali      -1.823202
# Ömer     -2.176361
# Yusuf    -0.305493
# Cennet    0.868030
# Furkan    0.511122
# Name: Seniorty, dtype: float64

# %%
new_df["Example"]=10

# %%
new_df
# Out:
#            Price       Age  Seniorty  Example
# Ali     0.634985  0.990881 -1.823202       10
# Ömer    0.282724 -1.775391 -2.176361       10
# Yusuf   0.384363  0.294062 -0.305493       10
# Cennet -0.883249  0.553144  0.868030       10
# Furkan -0.119375  0.538179  0.511122       10

# %%
new_df["Exampe"]=20

# %%
new_df.drop("Exampe" ,axis= 1)
# Out:
#            Price       Age  Seniorty  Example
# Ali     0.634985  0.990881 -1.823202       10
# Ömer    0.282724 -1.775391 -2.176361       10
# Yusuf   0.384363  0.294062 -0.305493       10
# Cennet -0.883249  0.553144  0.868030       10
# Furkan -0.119375  0.538179  0.511122       10

# %%
new_df
# Out:
#            Price       Age  Seniorty  Example  Exampe
# Ali     0.634985  0.990881 -1.823202       10      20
# Ömer    0.282724 -1.775391 -2.176361       10      20
# Yusuf   0.384363  0.294062 -0.305493       10      20
# Cennet -0.883249  0.553144  0.868030       10      20
# Furkan -0.119375  0.538179  0.511122       10      20

# %%
new_df.drop("Exampe", axis=1,inplace=True)

# %%
new_df
# Out:
#            Price       Age  Seniorty  Example
# Ali     0.634985  0.990881 -1.823202       10
# Ömer    0.282724 -1.775391 -2.176361       10
# Yusuf   0.384363  0.294062 -0.305493       10
# Cennet -0.883249  0.553144  0.868030       10
# Furkan -0.119375  0.538179  0.511122       10

# %%
new_df["Cennet"]=10

# %%
new_df
# Out:
#            Price       Age  Seniorty  Example  Cennet
# Ali     0.634985  0.990881 -1.823202       10      10
# Ömer    0.282724 -1.775391 -2.176361       10      10
# Yusuf   0.384363  0.294062 -0.305493       10      10
# Cennet -0.883249  0.553144  0.868030       10      10
# Furkan -0.119375  0.538179  0.511122       10      10

# %%
new_df.drop("Cennet",axis=1,inplace=True)

# %%
new_df
# Out:
#            Price       Age  Seniorty  Example
# Ali     0.634985  0.990881 -1.823202       10
# Ömer    0.282724 -1.775391 -2.176361       10
# Yusuf   0.384363  0.294062 -0.305493       10
# Cennet -0.883249  0.553144  0.868030       10
# Furkan -0.119375  0.538179  0.511122       10

# %%
new_df.drop("Ali",axis=0)
# Out:
#            Price       Age  Seniorty  Example
# Ömer    0.282724 -1.775391 -2.176361       10
# Yusuf   0.384363  0.294062 -0.305493       10
# Cennet -0.883249  0.553144  0.868030       10
# Furkan -0.119375  0.538179  0.511122       10

# %%
new_df.loc["Ömer","Price"]
# Out:
# np.float64(0.28272441014008254)

# %%
new_df.loc["Ömer","Price"]=200

# %%
new_df
# Out:
#              Price       Age  Seniorty  Example
# Ali       0.634985  0.990881 -1.823202       10
# Ömer    200.000000 -1.775391 -2.176361       10
# Yusuf     0.384363  0.294062 -0.305493       10
# Cennet   -0.883249  0.553144  0.868030       10
# Furkan   -0.119375  0.538179  0.511122       10

# %%
new_df[new_df>0]
# Out:
#              Price       Age  Seniorty  Example
# Ali       0.634985  0.990881       NaN       10
# Ömer    200.000000       NaN       NaN       10
# Yusuf     0.384363  0.294062       NaN       10
# Cennet         NaN  0.553144  0.868030       10
# Furkan         NaN  0.538179  0.511122       10

# %%
new_df[new_df["Price"]>1]
# Out:
#       Price       Age  Seniorty  Example
# Ömer  200.0 -1.775391 -2.176361       10

# %%
new_df[new_df["Age"]<0]
# Out:
#       Price       Age  Seniorty  Example
# Ömer  200.0 -1.775391 -2.176361       10

# %%
new_df.reset_index()
# Out:
#     index       Price       Age  Seniorty  Example
# 0     Ali    0.634985  0.990881 -1.823202       10
# 1    Ömer  200.000000 -1.775391 -2.176361       10
# 2   Yusuf    0.384363  0.294062 -0.305493       10
# 3  Cennet   -0.883249  0.553144  0.868030       10
# 4  Furkan   -0.119375  0.538179  0.511122       10

# %%
new_df.drop("Example", axis= 1 , inplace= True)

# %%
new_df
# Out:
#              Price       Age  Seniorty
# Ali       0.634985  0.990881 -1.823202
# Ömer    200.000000 -1.775391 -2.176361
# Yusuf     0.384363  0.294062 -0.305493
# Cennet   -0.883249  0.553144  0.868030
# Furkan   -0.119375  0.538179  0.511122

# %%
reset_frame=new_df.reset_index()

# %%
reset_frame
# Out:
#     index       Price       Age  Seniorty
# 0     Ali    0.634985  0.990881 -1.823202
# 1    Ömer  200.000000 -1.775391 -2.176361
# 2   Yusuf    0.384363  0.294062 -0.305493
# 3  Cennet   -0.883249  0.553144  0.868030
# 4  Furkan   -0.119375  0.538179  0.511122

# %%
index=["Al","Öm","Yus","Cen","Fur"]
new_df["New İndex"]=index

# %%
new_df
# Out:
#              Price       Age  Seniorty New İndex
# Ali       0.634985  0.990881 -1.823202        Al
# Ömer    200.000000 -1.775391 -2.176361        Öm
# Yusuf     0.384363  0.294062 -0.305493       Yus
# Cennet   -0.883249  0.553144  0.868030       Cen
# Furkan   -0.119375  0.538179  0.511122       Fur

# %%
new_df.set_index("New İndex" ,inplace=True)

# %%
new_df
# Out:
#                 Price       Age  Seniorty
# New İndex
# Al           0.634985  0.990881 -1.823202
# Öm         200.000000 -1.775391 -2.176361
# Yus          0.384363  0.294062 -0.305493
# Cen         -0.883249  0.553144  0.868030
# Fur         -0.119375  0.538179  0.511122

# %%
new_df.loc["Öm"]
# Out:
# Price       200.000000
# Age          -1.775391
# Seniorty     -2.176361
# Name: Öm, dtype: float64

# %%
#multi index

# %%
new_index=["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
inner_index=["Homer","Barge","Merge","Cartman","Kany","Kylie"]

# %%
zipped_index=list(zip(new_index , inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Barge'),
#  ('Simpson', 'Merge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kany'),
#  ('South Park', 'Kylie')]

# %%
zipped_index=pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',   'Barge'),
#             (   'Simpson',   'Merge'),
#             ('South Park', 'Cartman'),
#             ('South Park',    'Kany'),
#             ('South Park',   'Kylie')],
#            )

# %%
sample_values=np.ones((6,2))

# %%
big_df=pd.DataFrame(sample_values , index=zipped_index, columns=["Age","Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Barge    1.0     1.0
#            Merge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kany     1.0     1.0
#            Kylie    1.0     1.0

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Barge  1.0     1.0
# Merge  1.0     1.0

# %%
big_df.loc["South Park"].loc["Kylie"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Kylie, dtype: float64

# %%
big_df.loc["Simpson"].loc["Merge"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Merge, dtype: float64
