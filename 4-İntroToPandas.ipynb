# %%
import numpy as np

# %%
import pandas as pd

# %%
notlar={"Ali":50,"Yusuf":60,"Cennet":70,"Ömer":80}

# %%
pd.Series(notlar)
# Out:
# Ali       50
# Yusuf     60
# Cennet    70
# Ömer      80
# dtype: int64

# %%
my_list=[10,20,30,40,50,60]
print(my_list)
pd.Series(my_list)
# Out:
# [10, 20, 30, 40, 50, 60]
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
numpy_array=np.random.randint(1,200,5)

# %%
print(numpy_array)
# Out:
# [ 82 135 131 109  80]

# %%
pd.Series(numpy_array)
# Out:
# 0     82
# 1    135
# 2    131
# 3    109
# 4     80
# dtype: int32

# %%
names=["Ali","Yusuf","Cennet","Ömer"]
grades=[50,60,70,80]
#pd.Series(names)
#pd.Series(grades)
pd.Series(grades,names)
# Out:
# Ali       50
# Yusuf     60
# Cennet    70
# Ömer      80
# dtype: int64

# %%
pd.Series(data=grades , index=names)
# Out:
# Ali       50
# Yusuf     60
# Cennet    70
# Ömer      80
# dtype: int64

# %%
content_result=pd.Series(data=[10,20,50], index=["Ömer","Ali","Yusuf"])
content_result2=pd.Series(data=[50,40,10], index=["Ömer","Ali","Yusuf"])
content_result["Ömer"]
content_result2["Ali"]
# Out:
# np.int64(40)

# %%
final_result= content_result + content_result2

# %%
print(final_result)
# Out:
# Ömer     60
# Ali      60
# Yusuf    60
# dtype: int64

# %%
content_result - content_result2
# Out:
# Ömer    -40
# Ali     -20
# Yusuf    40
# dtype: int64

# %%
content_result * content_result2
# Out:
# Ömer     500
# Ali      800
# Yusuf    500
# dtype: int64

# %%
content_result  / content_result2
# Out:
# Ömer     0.2
# Ali      0.5
# Yusuf    5.0
# dtype: float64

# %%
example_series = pd.Series([10,20,30,40], ["a","b","c","d"])
example_series2 = pd.Series([5,10,50,3], ["a","d","b","f"])
print(example_series+example_series2)
# Out:
# a    15.0
# b    70.0
# c     NaN
# d    50.0
# f     NaN
# dtype: float64
