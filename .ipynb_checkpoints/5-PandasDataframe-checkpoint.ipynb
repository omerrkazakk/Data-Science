# %%
import numpy as np

# %%
import pandas as pd

# %%
example_data= np.random.randn(5,3)
example_data
# Out:
# array([[-2.4191414 ,  0.06629971, -1.88951549],
#        [-0.62611844,  1.79098301,  0.42716323],
#        [-1.28999003,  0.17212863,  0.49630303],
#        [-0.85570009, -0.63541188,  0.22459076],
#        [ 0.64887323,  2.53722142,  1.00341618]])

# %%
example_dataframe=pd.DataFrame(example_data)

# %%
print(example_dataframe)
# Out:
#           0         1         2
# 0  0.538545 -0.989808 -0.004554
# 1 -0.565192  0.316676  0.606933
# 2 -0.021813 -0.829544  0.061596
# 3 -1.466759  0.364854 -0.494688
# 4  1.669177 -1.069468 -0.462833

# %%
type(example_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
print(example_dataframe[0])
# Out:
# 0    0.538545
# 1   -0.565192
# 2   -0.021813
# 3   -1.466759
# 4    1.669177
# Name: 0, dtype: float64

# %%
type(example_dataframe[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(example_data, index= ["Ali","Ömer","Yusuf","Cennet","Furkan"], columns= ["Price","Age","Seniorty"])
new_df
# Out:
#            Price       Age  Seniorty
# Ali    -2.419141  0.066300 -1.889515
# Ömer   -0.626118  1.790983  0.427163
# Yusuf  -1.289990  0.172129  0.496303
# Cennet -0.855700 -0.635412  0.224591
# Furkan  0.648873  2.537221  1.003416

# %%
print(new_df["Age"])
# Out:
# Ali       0.066300
# Ömer      1.790983
# Yusuf     0.172129
# Cennet   -0.635412
# Furkan    2.537221
# Name: Age, dtype: float64

# %%
print(new_df["Seniorty"])
# Out:
# Ali      -1.889515
# Ömer      0.427163
# Yusuf     0.496303
# Cennet    0.224591
# Furkan    1.003416
# Name: Seniorty, dtype: float64

# %%
print(new_df[["Age","Price"]])
# Out:
#              Age     Price
# Ali     0.066300 -2.419141
# Ömer    1.790983 -0.626118
# Yusuf   0.172129 -1.289990
# Cennet -0.635412 -0.855700
# Furkan  2.537221  0.648873

# %%
print(new_df.loc["Ömer"])
# Out:
# Price      -0.626118
# Age         1.790983
# Seniorty    0.427163
# Name: Ömer, dtype: float64

# %%
print(new_df.loc["Cennet"])
# Out:
# Price      -0.855700
# Age        -0.635412
# Seniorty    0.224591
# Name: Cennet, dtype: float64

# %%
print(new_df.iloc[4])
# Out:
# Price       0.648873
# Age         2.537221
# Seniorty    1.003416
# Name: Furkan, dtype: float64

# %%
#: tüm satırları seçer sonraki sayı ise istenilen indexteki kolonu getirir.
print(new_df.iloc[:,2])
# Out:
# Ali      -1.889515
# Ömer      0.427163
# Yusuf     0.496303
# Cennet    0.224591
# Furkan    1.003416
# Name: Seniorty, dtype: float64
